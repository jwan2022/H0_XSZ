# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
h70 = [1.2635901, 1.2285727, 1.4000466, 0.90895700, 1.1479442, 1.0707163, 1.0416174, 0.92511159, 1.2250605, 
         1.3000808, 1.1407545, 0.93993878, 1.1322540, 1.1051780]

h50 = [1.3675833, 1.5004276, 1.6536793, 1.1365377, 1.4255445, 1.2625648, 1.1749419, 1.0554847, 1.4673408, 
         1.5586258, 1.4176997, 1.0326066, 1.4567769, 1.0158851]

ratio = np.array(h50)/np.array(h70)

# %%
np.median(ratio)
# Out:
# 1.1894651267772627

# %%
np.sqrt(7/5)
# Out:
# 1.1832159566199232

# %%
1.3675833/1.18
# Out:
# 1.1589688983050848

# %%
plt.hist(ratio)
plt.show()

# %%
ratio
# Out:
# array([1.08229979, 1.22127702, 1.18116018, 1.25037565, 1.24182386,
#        1.17917771, 1.12799757, 1.1409269 , 1.19777007, 1.19886841,
#        1.24277371, 1.09858921, 1.2866167 , 0.91920496])
